# %%
#1-
# !pip install gdown

import gdown, zipfile, os

# ---- مشخصات فایل ----
file_id = "1RdxkWe1JM-GADdtDf6QpNN3tGgmNEvIE"   # همون id از لینکت
destination = "BookCovers-5-full-c.zip"                      # اسم فایل نهایی

# ---- دانلود ----
gdown.download(f"https://drive.google.com/uc?id={file_id}", destination, quiet=False)

# ---- اگر فایل zip بود، اکسترکت کن ----
if destination.endswith(".zip"):
    extract_path = "extracted_files"
    os.makedirs(extract_path, exist_ok=True)

    with zipfile.ZipFile(destination, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

    print(f"✅ فایل {destination} در پوشه {extract_path} اکسترکت شد.")
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.29.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.5.20)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From (original): https://drive.google.com/uc?id=1RdxkWe1JM-GADdtDf6QpNN3tGgmNEvIE
# From (redirected): https://drive.google.com/uc?id=1RdxkWe1JM-GADdtDf6QpNN3tGgmNEvIE&confirm=t&uuid=6413d343-e0ab-490e-977e-82525812ef70
# To: /content/BookCovers-5-full-c.zip
# 100%|██████████| 92.4M/92.4M [00:00<00:00, 228MB/s]
# ✅ فایل BookCovers-5-full-c.zip در پوشه extracted_files اکسترکت شد.

# %%
#2-
#importing the essential libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import confusion_matrix, classification_report
import itertools
################
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow.keras
from PIL import Image, ImageOps
from tensorflow.keras.preprocessing.image import *
# %matplotlib inline
from tensorflow import keras
from keras import *
import keras
import cv2
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns
from tensorflow.keras import regularizers
from keras.regularizers import l2
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
 #3-
 ! pip install unzip
 # !unzip "/content/BookCovers-5-full-c.zip" -d "BookCovers-5-full-c"
# Out:
# Requirement already satisfied: unzip in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Archive:  /content/BookCovers-5-full-c.zip
# replace BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (1).jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: all
# error:  invalid response [all]
# replace BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (1).jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: All
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (1).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (10).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (100).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (101).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (102).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (103).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (104).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (105).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (106).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (107).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (108).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (109).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (11).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (110).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (111).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (112).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (113).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (114).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (115).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (116).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (117).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (118).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (119).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (12) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (120).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (121).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (122).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (123) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (124).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (125).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (126).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (127).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (128).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (129).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (13).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (130).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (131).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (132).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (133).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (134).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (135).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (136).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (137).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (138).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (139).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (14) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (140).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (141).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (142).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (143).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (144).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (145) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (146) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (147).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (148).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (149).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (15).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (150).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (151).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (152).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (153).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (154).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (155).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (156).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (157).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (158).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (159).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (16).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (160).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (161).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (162).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (163).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (164).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (165).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (166).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (167).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (168).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (169).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (17).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (170).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (171) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (173).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (175).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (176).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (177).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (179).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (18).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (180).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (181).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (182).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (183).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (184).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (185).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (187).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (189).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (19).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (190).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (191).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (192).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (193).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (194).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (195).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (197).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (198).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (199).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (2) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (20).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (201).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (202).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (203).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (204).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (205).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (206).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (207).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (208).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (209).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (21).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (210).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (211).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (212).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (213).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (214).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (215).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (216).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (217).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (218).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (219).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (22).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (220).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (221).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (222).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (223).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (224).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (225).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (226).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (227).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (228).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (229).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (23).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (230).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (231).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (232).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (233).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (234).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (235).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (236).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (237).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (238).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (239).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (24).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (240).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (241).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (242).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (243).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (244).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (245).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (246) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (247).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (248).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (249).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (25).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (250).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (251).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (252).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (253).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (254).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (255).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (256) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (257).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (258).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (259).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (26).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (260).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (261).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (262).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (263).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (264).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (265).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (266).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (267).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (268).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (269).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (27).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (270).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (271).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (272).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (273).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (274).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (275).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (276).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (277).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (278).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (279).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (28).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (280).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (281).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (282).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (283).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (284).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (285).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (286).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (287).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (288).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (289).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (29).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (290).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (3).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (30) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (31).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (32).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (33).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (34).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (35) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (36).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (37).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (38).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (39).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (4).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (40).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (41).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (42).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (43).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (44).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (45).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (46).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (47).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (48).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (49).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (5).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (50).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (51).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (52).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (53).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (54).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (55).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (56).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (57).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (58).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (59).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (6).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (60).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (61).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (62).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (63).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (64) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (65).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (66).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (67).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (68) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (69).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (7).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (70).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (71).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (72).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (73).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (74) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (75) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (76).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (77) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (78).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (79).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (8).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (80).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (81).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (82).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (83).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (84).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (85).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (86).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (87).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (88).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (89).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (9) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (90).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (91).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (92).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (93).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (94).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (95).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (96).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (97).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (98).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/3 (99).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (1).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (10).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (11).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (12).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (13) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (14).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (15).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (16).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (17).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (18).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (19).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (2).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (20).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (21) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (22).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (23).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (24).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (25).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (26).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (27).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (28).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (29).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (3).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (30).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (31).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (32).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (33).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (34).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (35).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (36).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (37).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (38).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (39).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (4).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (40).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (41).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (42).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (43).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (44).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (45).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (46).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (47).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (48).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (49).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (5).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (50).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (51).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (52).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (53).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (54).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (55).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (56).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (57).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (58).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (59).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (6).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (60).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (61).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (62) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (63).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (64).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (65).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (66) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (67).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (68).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (69).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (7).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (70).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (71).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (72).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (73).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (74).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (75).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (76).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (8).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/falsafe va ravanshenasi/c (9).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (1).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (10).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (100).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (101).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (102).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (103).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (104).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (105).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (106).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (107).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (108).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (109).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (11).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (110).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (111).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (112).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (113).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (114).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (115).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (116).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (117).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (118).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (119).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (12).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (120).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (121).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (122).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (123).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (124).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (125).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (126).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (127).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (128).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (129).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (13).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (130).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (131).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (132).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (133).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (134).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (135).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (136).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (137).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (138).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (139).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (14).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (140).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (141).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (142).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (143).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (144).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (145).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (146).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (147).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (148).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (149).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (15).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (150).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (151).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (153).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (154).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (155).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (157).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (159).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (16).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (161).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (163).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (164).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (165).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (166).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (167).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (168).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (169).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (17).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (170).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (171).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (172).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (173).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (174).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (175).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (176).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (177).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (178).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (179).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (18).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (180).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (181).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (182).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (183).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (184).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (185).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (186).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (187).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (188).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (189).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (19).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (191).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (192).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (193).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (195).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (197).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (198).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (199).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (2).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (20).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (200).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (201).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (202).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (203).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (204).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (205).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (206).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (207).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (208).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (209).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (21).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (210).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (211).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (212).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (214).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (215).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (216).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (217).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (218).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (219).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (22).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (220).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (221).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (222).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (223).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (224).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (225).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (226).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (227).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (228).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (229).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (23).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (230).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (231).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (232).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (233).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (234).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (235).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (236).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (237).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (238).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (239).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (24).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (240).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (241).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (242).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (243).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (244).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (245).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (246).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (247).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (248).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (249).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (25).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (250).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (251).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (252).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (253).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (254).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (255).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (256).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (257).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (258).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (259).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (26).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (260).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (261).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (262).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (263).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (264).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (265).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (266).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (267).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (268).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (269).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (27).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (270).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (271).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (272).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (273).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (274).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (275).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (276).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (277).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (278).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (279).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (28).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (280).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (281).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (282).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (283).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (284).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (285).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (286).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (287).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (288).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/koliat/5 (289).jpg
# ...
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (238).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (239).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (24).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (240).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (241).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (242).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (243).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (244).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (245).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (246).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (247).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (248).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (249).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (25).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (250).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (251) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (252).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (253).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (254).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (255).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (256).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (257).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (258).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (259).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (26).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (260).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (261) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (262).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (263).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (264).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (265) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (266).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (267).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (268).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (269).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (27).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (270).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (271).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (272).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (273).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (274).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (275).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (276).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (277).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (278).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (279).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (28).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (280).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (281).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (282).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (283).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (29).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (3).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (30).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (31).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (32).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (33).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (34).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (35).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (36) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (37).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (38).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (39).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (4).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (40).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (41).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (42).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (43).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (44).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (45).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (46).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (47).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (48).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (49).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (5).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (50).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (51).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (52).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (53).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (54).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (55).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (56).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (57).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (58).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (59).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (6).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (60).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (61).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (62).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (63).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (64).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (65).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (66).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (67).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (68).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (69).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (7).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (70).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (71).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (72).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (73).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (74).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (75) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (76) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (77).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (78).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (79).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (8).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (80).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (81).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (82).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (83).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (84) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (85).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (86).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (87).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (88).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (89).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (9).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (90).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (91).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (92).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (93).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (94).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (95).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (96).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (97).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (98).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/10 (99).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (1).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (10).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (11).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (12).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (13).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (14).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (15).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (16).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (17).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (18).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (19).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (2).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (20).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (21).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (22).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (23).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (24).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (25).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (26) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (27).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (28).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (29).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (3).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (30).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (31).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (32).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (33).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (34).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (35).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (36).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (37) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (38).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (39).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (4).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (40).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (41).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (42).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (43) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (44).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (45).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (46).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (47).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (48).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (49).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (5).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (50).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (51).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (52).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (53).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (54).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (55).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (56).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (57).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (58) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (59).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (6).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (60).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (61).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (62).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (63).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (64) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (65) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (66).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (67).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (68).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (69).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (7).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (70).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (71).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (72).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (73).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (74).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (75).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (76).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (77).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (78).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (79).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (8).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (85).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (86).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (87).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (88).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (89).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (9).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (90) - Copy.jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (91).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (92).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (93).jpg
#   inflating: BookCovers-5-full-c/BookCovers-5-full-c/zaban/j (94).jpg

# %%
#5-
# !pip install easyocr
# Out:
# Requirement already satisfied: easyocr in /usr/local/lib/python3.12/dist-packages (1.7.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.26.0+cu128)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from easyocr) (4.13.0.92)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from easyocr) (1.16.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from easyocr) (11.3.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.25.2)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.6.10)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from easyocr) (6.0.3)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.1.2)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.12/dist-packages (from easyocr) (1.4.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from easyocr) (1.13.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.29.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->easyocr) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->easyocr) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->easyocr) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->easyocr) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->easyocr) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->easyocr) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->easyocr) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->easyocr) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->easyocr) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->easyocr) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->easyocr) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->easyocr) (12.8.90)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (2026.4.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (26.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (0.5)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch->easyocr) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->easyocr) (3.0.3)

# %%
#4-
# !pip install split-folders
import splitfolders
path = "/content/BookCovers-5-full-c/BookCovers-5-full-c"
splitfolders.ratio(path,seed=200, output="/content/BookCovers-split", ratio=(0.9,0, 0.1))
# Out:
# Requirement already satisfied: split-folders in /usr/local/lib/python3.12/dist-packages (0.6.1)
# Copying files: 1773 files [00:00, 3945.74 files/s]

# %%
#ba nemodar loss,tsne#fusion model embeding 256
# =========================
# Multi-Stage Vision/Text → Late Fusion Classifier (with EMA) + Metrics/Plots/TSNE/CM
# =========================

# -------- Libraries --------
import os, re, random, copy
import math
import torch, torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms, models
from transformers import AutoTokenizer, AutoModel, get_linear_schedule_with_warmup
from torch.optim import AdamW
import pandas as pd
import numpy as np
import easyocr
from PIL import Image
import torch.nn.functional as F

# extra for metrics/plots
from sklearn.metrics import f1_score, confusion_matrix, recall_score
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# -------- Parameters --------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_classes = 5

# paths
train_dir = "/content/BookCovers-split/train"
test_dir  = "/content/BookCovers-split/test"
ocr_cache_dir = "ocr_cache"
os.makedirs(ocr_cache_dir, exist_ok=True)
train_csv = os.path.join(ocr_cache_dir, "train.csv")
test_csv  = os.path.join(ocr_cache_dir, "test.csv")

# results root
RESULTS_DIR = "results"
os.makedirs(RESULTS_DIR, exist_ok=True)

# common
seed = 42
torch.manual_seed(seed); random.seed(seed); np.random.seed(seed)


import torch, numpy as np, random, os

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    # برای جلوگیری از non-deterministic بودن cuDNN
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)
# ======= Helpers: text cleaning / OCR CSV =======
def clean_ocr_text(text: str) -> str:
    text = (text or "").lower()
    text = re.sub(r"[^a-zA-Z0-9\u0600-\u06FF\s]", " ", text)
    text = text.replace("ي","ی")
    text = text.replace("ك","ک")
    return " ".join(text.split()).strip()

def build_ocr_csv(imagefolder_dir, csv_path, use_gpu=True):
    if os.path.exists(csv_path):
        print(f"[!] CSV exists: {csv_path}")
        return
    print(f"[+] Building OCR CSV for: {imagefolder_dir}")
    reader = easyocr.Reader(['en','fa'], gpu=use_gpu)
    img_folder = datasets.ImageFolder(imagefolder_dir)
    rows = []
    for path, label in img_folder.samples:
        try:
            text_list = reader.readtext(path, detail=0)
            text = " ".join(text_list) if len(text_list) > 0 else "empty"
        except Exception as e:
            print(f"[OCR ERROR] {path}: {e}")
            text = "empty"
        rows.append({"path": path, "label": label, "text": text})
    df = pd.DataFrame(rows)
    df.to_csv(csv_path, index=False, encoding="utf-8")
    print(f"[+] OCR CSV saved: {csv_path} (rows={len(df)})")

# build OCR caches (idempotent)
build_ocr_csv(train_dir, train_csv)
build_ocr_csv(test_dir,  test_csv)

# ======= Utils: metrics, plotting, saving =======
def ensure_dir(p):
    os.makedirs(p, exist_ok=True)
    return p

def save_fig_dual(fig, path_no_ext):
    fig.savefig(path_no_ext + ".png", dpi=300, bbox_inches="tight")
    fig.savefig(path_no_ext + ".pdf", dpi=300, bbox_inches="tight")
    plt.close(fig)

from sklearn.metrics import precision_recall_fscore_support

def compute_metrics(y_true, y_pred, num_classes):
    y_true = np.asarray(y_true); y_pred = np.asarray(y_pred)
    acc = (y_true == y_pred).mean() if len(y_true)>0 else 0.0
    f1  = f1_score(y_true, y_pred, average="macro") if len(y_true)>0 else 0.0
    sens = recall_score(y_true, y_pred, average="macro", zero_division=0) if len(y_true)>0 else 0.0
    cm = confusion_matrix(y_true, y_pred, labels=list(range(num_classes)))
    cm_sum = cm.sum()

    # specificity (macro)
    specs = []
    for i in range(num_classes):
        tp = cm[i, i]
        fp = cm[:, i].sum() - tp
        fn = cm[i, :].sum() - tp
        tn = cm_sum - (tp + fp + fn)
        spec_i = tn / (tn + fp + 1e-8)
        specs.append(spec_i)
    spec = float(np.mean(specs)) if len(specs)>0 else 0.0
    gmean = float(np.sqrt(max(sens,0.0) * max(spec,0.0)))

    # ---------- per-class metrics ----------
    per_class = []
    for i in range(num_classes):
        tp = cm[i, i]
        fp = cm[:, i].sum() - tp
        fn = cm[i, :].sum() - tp
        tn = cm_sum - (tp + fp + fn)

        acc_i  = (tp + tn) / (tp+tn+fp+fn+1e-8)
        sens_i = tp / (tp+fn+1e-8)      # recall
        spec_i = tn / (tn+fp+1e-8)
        f1_i   = 2*tp / (2*tp+fp+fn+1e-8)
        gmean_i = np.sqrt(sens_i * spec_i)

        per_class.append({
            "class": i,
            "acc": acc_i,
            "f1": f1_i,
            "sensitivity": sens_i,
            "specificity": spec_i,
            "gmean": gmean_i
        })

    return acc, f1, sens, spec, gmean, cm, per_class



def plot_confusion(cm, title="Confusion Matrix"):
    fig, ax = plt.subplots(figsize=(6,5))
    im = ax.imshow(cm, interpolation='nearest')
    ax.set_title(title)
    ax.set_xlabel("Predicted")
    ax.set_ylabel("True")
    tick_marks = np.arange(cm.shape[0])
    ax.set_xticks(tick_marks); ax.set_yticks(tick_marks)
    # annotate
    thresh = cm.max() / 2. if cm.size>0 else 0.5
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, int(cm[i, j]), ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black", fontsize=8)
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    return fig

def plot_curve(epochs, train_vals, test_vals, title, ylabel):
    fig, ax = plt.subplots(figsize=(7,4))
    ax.plot(epochs, train_vals, label="train")
    ax.plot(epochs, test_vals, label="test")
    ax.set_title(title); ax.set_xlabel("epoch"); ax.set_ylabel(ylabel)
    ax.legend()
    return fig

def run_tsne_and_plot(features, labels, title, out_no_ext, max_points=2000, perplexity=30, use_all=False):
    """
    Run t-SNE and plot results.

    Args:
        features: لیست یا آرایه ویژگی‌ها
        labels: لیست یا آرایه لیبل‌ها
        title: عنوان نمودار
        out_no_ext: مسیر فایل بدون پسوند برای ذخیره
        max_points: حداکثر تعداد نمونه‌ها برای سرعت
        perplexity: پارامتر perplexity t-SNE
        use_all: اگر True شود، تمام داده‌ها استفاده می‌شوند، در غیر اینصورت حداکثر max_points نمونه
    """
    X = np.asarray(features)
    y = np.asarray(labels)
    if len(X) == 0:
        return

    # زیرنمونه‌گیری فقط وقتی use_all=False
    if not use_all and len(X) > max_points:
        idx = np.random.RandomState(0).choice(len(X), size=max_points, replace=False)
        X = X[idx]
        y = y[idx]

    perplexity = min(perplexity, max(5, len(X)//3))
    tsne = TSNE(n_components=2, perplexity=perplexity, random_state=0, init='pca', learning_rate='auto')
    emb = tsne.fit_transform(X)

    fig, ax = plt.subplots(figsize=(6,5))
    sc = ax.scatter(emb[:,0], emb[:,1], c=y, s=10)
    ax.set_title(title)
    ax.set_xticks([]); ax.set_yticks([])
    save_fig_dual(fig, out_no_ext)


# ======= EMA =======
class EMA:
    def __init__(self, model, decay=0.98):
        self.decay = decay
        self.shadow = {n: p.clone().detach() for n,p in model.named_parameters() if p.requires_grad}
        self.backup = {}

    @torch.no_grad()
    def update(self, model):
        for n, p in model.named_parameters():
            if p.requires_grad and n in self.shadow:
                self.shadow[n].mul_(self.decay).add_(p.data, alpha=1-self.decay)

    def apply_shadow(self, model):
        self.backup = {}
        for n, p in model.named_parameters():
            if p.requires_grad and n in self.shadow:
                self.backup[n] = p.data.clone()
                p.data.copy_(self.shadow[n])

    def restore(self, model):
        for n, p in model.named_parameters():
            if p.requires_grad and n in self.backup:
                p.data.copy_(self.backup[n])
        self.backup = {}

# ======= Vision Stage =======
# Transforms
train_transform_img = transforms.Compose([  # # 为什么弄个twice
                        transforms.Resize(224),
                        #transforms.RandomHorizontalFlip(p=0.5),
                        #transforms.RandomRotation(10),
                        transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1),
                        transforms.ToTensor(),
                        transforms.Normalize([0.485, 0.456, 0.406],
                                            [0.229, 0.224, 0.225])     ])
test_transform_img = transforms.Compose([
                        transforms.Resize(224),
                        transforms.ToTensor(),
                        transforms.Normalize([0.485, 0.456, 0.406],
                                            [0.229, 0.224, 0.225])
                    ])


# Loaders
batch_size_img = 32
train_dataset_img = datasets.ImageFolder(train_dir, transform=train_transform_img)
test_dataset_img  = datasets.ImageFolder(test_dir, transform=test_transform_img)
train_loader_img = DataLoader(train_dataset_img, batch_size=batch_size_img, shuffle=True, num_workers=2, pin_memory=True)
test_loader_img  = DataLoader(test_dataset_img,  batch_size=batch_size_img, shuffle=False, num_workers=2, pin_memory=True)

# Vision model: backbone + head
class VisionBackbone(nn.Module):
    def __init__(self, out_dim=1024):
        super().__init__()
        m = models.densenet121(pretrained=True)
        num_ftrs = m.classifier.in_features  # 1024
        m.classifier = nn.Identity()
        self.backbone = m
        self.out_dim = num_ftrs
        self.post = nn.Identity()  # reserved (e.g., LayerNorm)
    def forward(self, x):
        feats = self.backbone(x)               # [B, 1024]
        return self.post(feats)                # [B, 1024]

class VisionClassifier(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.backbone = VisionBackbone()
        self.head = nn.Linear(self.backbone.out_dim, num_classes)
    def forward(self, x):
        feats = self.backbone(x)
        return self.head(feats)

@torch.no_grad()
def evaluate_img_full(model, loader, criterion):
    model.eval()
    total_loss = 0.0; n = 0
    y_true, y_pred = [], []
    all_feats = []
    for imgs, labels in loader:
        imgs, labels = imgs.to(device), labels.to(device)
        feats = model.backbone(imgs)
        logits = model.head(feats)
        loss = criterion(logits, labels)
        total_loss += float(loss.item()) * labels.size(0); n += labels.size(0)
        preds = logits.argmax(1)
        y_true.extend(labels.cpu().numpy().tolist())
        y_pred.extend(preds.cpu().numpy().tolist())
        all_feats.append(feats.cpu().numpy())
    avg_loss = total_loss / max(n, 1)
    feats_np = np.vstack(all_feats) if len(all_feats)>0 else np.zeros((0, model.backbone.out_dim))
    return avg_loss, y_true, y_pred, feats_np

def train_vision(num_epochs=40, lr=1e-4, weight_decay=0.0):
    stage = "vision"
    stage_dir = ensure_dir(os.path.join(RESULTS_DIR, stage))
    model = VisionClassifier(num_classes).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    ema = EMA(model, decay=0.98)
    best_acc = 0.0
    best_state = None

    # history holders
    train_losses, test_losses = [], []
    train_accs,   test_accs   = [], []
    train_f1s,    test_f1s    = [], []
    train_sens,   test_sens   = [], []
    train_spec,   test_spec   = [], []
    train_gmean,  test_gmean  = [], []
    metrics_rows = []

    for epoch in range(num_epochs):
        model.train()
        running, correct, total = 0.0, 0, 0
        for imgs, labels in train_loader_img:
            imgs, labels = imgs.to(device), labels.to(device)
            optimizer.zero_grad()
            logits = model(imgs)
            loss = criterion(logits, labels)
            loss.backward()
            optimizer.step()
            ema.update(model)

            running += loss.item()*imgs.size(0)
            correct += (logits.argmax(1)==labels).sum().item()
            total += labels.size(0)

        train_loss_epoch = running/max(total,1)

        # eval with EMA weights on train+test (for metrics)
        ema.apply_shadow(model)
        tr_loss, tr_y, tr_p, tr_feats = evaluate_img_full(model, train_loader_img, criterion)
        te_loss, te_y, te_p, te_feats = evaluate_img_full(model, test_loader_img,  criterion)
        ema.restore(model)

        tr_acc, tr_f1, tr_sens, tr_spec, tr_gm, tr_cm,tr_pc  = compute_metrics(tr_y, tr_p, num_classes)
        te_acc, te_f1, te_sens, te_spec, te_gm, te_cm,te_pc  = compute_metrics(te_y, te_p, num_classes)

        # keep histories (use eval losses for consistency)
        train_losses.append(tr_loss)
        test_losses.append(te_loss)
        train_accs.append(tr_acc); test_accs.append(te_acc)
        train_f1s.append(tr_f1);   test_f1s.append(te_f1)
        train_sens.append(tr_sens);test_sens.append(te_sens)
        train_spec.append(tr_spec);test_spec.append(te_spec)
        train_gmean.append(tr_gm); test_gmean.append(te_gm)

        metrics_rows.append([epoch+1,"train",tr_loss,tr_acc,tr_f1,tr_sens,tr_spec,tr_gm])
        metrics_rows.append([epoch+1,"test", te_loss,te_acc,te_f1,te_sens,te_spec,te_gm])

        print(f"[Vision] Epoch {epoch+1}/{num_epochs} - TrainLoss {train_loss_epoch:.4f} - TrainAcc(EvalEMA) {tr_acc:.4f} - TestAcc(EvalEMA) {te_acc:.4f}")

        if te_acc>best_acc:
            best_acc = te_acc

            ema.apply_shadow(model)
            best_state = copy.deepcopy(model.state_dict())
            ema.restore(model)
            # محاسبه متریک‌های per-class روی تست
            _, _, _, _, _, _, te_pc = compute_metrics(te_y, te_p, num_classes)

            # ذخیره CSV
            rows = []
            for pc in te_pc:
                rows.append([stage, pc["class"], pc["acc"], pc["f1"],
                            pc["sensitivity"], pc["specificity"], pc["gmean"]])
            df = pd.DataFrame(rows, columns=["stage","class","acc","f1","sensitivity","specificity","gmean"])
            df.to_csv(os.path.join(stage_dir,"best_per_class.csv"), index=False)





    # export final model with best EMA
    final_model = VisionClassifier(num_classes).to(device)
    final_model.load_state_dict(best_state)
    os.makedirs("checkpoints", exist_ok=True)
    torch.save(final_model.state_dict(), "checkpoints/vision_best_ema.pt")
    print(f"[Vision] Best TestAcc(EMA): {best_acc:.4f}  | saved to checkpoints/vision_best_ema.pt")

    # ---- Save epoch CSV and curves ----
    df = pd.DataFrame(metrics_rows, columns=["epoch","split","loss","acc","f1","sensitivity","specificity","gmean"])
    df.to_csv(os.path.join(stage_dir,"metrics.csv"), index=False)

    epochs = list(range(1, len(train_losses)+1))
    fig = plot_curve(epochs, train_losses, test_losses, "Vision Loss", "loss")
    save_fig_dual(fig, os.path.join(stage_dir, "curve_loss"))
    fig = plot_curve(epochs, train_accs, test_accs, "Vision Accuracy", "accuracy")
    save_fig_dual(fig, os.path.join(stage_dir, "curve_acc"))

    # ---- Final CM & TSNE using best model ----
    # evaluate again on best model
    #ema.apply_shadow(final_model)

    final_model.eval()
    tr_loss, tr_y, tr_p, tr_feats = evaluate_img_full(final_model, train_loader_img, nn.CrossEntropyLoss())
    te_loss, te_y, te_p, te_feats = evaluate_img_full(final_model, test_loader_img,  nn.CrossEntropyLoss())
    _, _, _, _, _, tr_cm,tr_pc = compute_metrics(tr_y, tr_p, num_classes)
    _, _, _, _, _, te_cm,te_pc = compute_metrics(te_y, te_p, num_classes)
    #ema.restore(final_model)

    # CM save
    pd.DataFrame(tr_cm).to_csv(os.path.join(stage_dir,"cm_train.csv"), index=False)
    pd.DataFrame(te_cm).to_csv(os.path.join(stage_dir,"cm_test.csv"),  index=False)
    fig = plot_confusion(tr_cm, "Vision Confusion Matrix (Train)")
    save_fig_dual(fig, os.path.join(stage_dir,"cm_train"))
    fig = plot_confusion(te_cm, "Vision Confusion Matrix (Test)")
    save_fig_dual(fig, os.path.join(stage_dir,"cm_test"))

    # TSNE
    run_tsne_and_plot(tr_feats, tr_y, "Vision t-SNE (Train)", os.path.join(stage_dir,"tsne_train"))
    run_tsne_and_plot(te_feats, te_y, "Vision t-SNE (Test)",  os.path.join(stage_dir,"tsne_test"))

    return "checkpoints/vision_best_ema.pt"

# ======= Text Stage =======
class OCRTextDataset(Dataset):
    def __init__(self, csv_file, tokenizer, max_len=256, oversample_short=2):
        self.df = pd.read_csv(csv_file)
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.oversample_short = oversample_short
        self.data = self._oversample_short_texts()

    def _oversample_short_texts(self):
        rows = []
        for _, row in self.df.iterrows():
            text = clean_ocr_text(str(row["text"]))
            count = self.oversample_short if len(text.split()) < 3 else 1
            for _ in range(count):
                rows.append({"path": row["path"], "label": int(row["label"]), "text": text})
        return rows

    def __len__(self): return len(self.data)

    def __getitem__(self, idx):
        row = self.data[idx]
        enc = self.tokenizer(row["text"], padding='max_length', truncation=True,
                             max_length=self.max_len, return_tensors='pt')
        return {
            "input_ids": enc['input_ids'].squeeze(0),
            "attention_mask": enc['attention_mask'].squeeze(0),
            "label": row["label"]
        }

class TextBackbone(nn.Module):
    def __init__(self, model_name="bert-base-multilingual-cased"):
        super().__init__()
        self.bert = AutoModel.from_pretrained(
    "HooshvareLab/bert-base-parsbert-uncased"
)
        self.out_dim = self.bert.config.hidden_size  # 768
        self.norm = nn.LayerNorm(self.out_dim)

    def forward(self, input_ids, attention_mask):
        out = self.bert(
    input_ids=input_ids,
    attention_mask=attention_mask,
    return_dict=True
)

        token_embeddings = out.last_hidden_state

        input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()

        sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)

        sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)

        mean_embeddings = sum_embeddings / sum_mask

        return self.norm(mean_embeddings)

class TextClassifier(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.backbone = TextBackbone()
        self.drop = nn.Dropout(0.3)
        self.fc = nn.Sequential(
    nn.Linear(self.backbone.out_dim, 512),
    nn.ReLU(),
    nn.Dropout(0.3),
    nn.Linear(512, num_classes)
)

    def forward(self, input_ids, attention_mask):
        feats = self.backbone(input_ids, attention_mask)
        return self.fc(self.drop(feats))

@torch.no_grad()
def evaluate_text_full(model, loader, criterion):
    model.eval()
    total_loss = 0.0; n = 0
    y_true, y_pred = [], []
    all_feats = []
    for batch in loader:
        ids = batch["input_ids"].to(device)
        mask = batch["attention_mask"].to(device)
        labels = batch["label"]
        if not torch.is_tensor(labels):
            labels = torch.tensor(labels, dtype=torch.long)
        labels = labels.to(device)
        feats = model.backbone(ids, mask)
        logits = model.fc(model.drop(feats))
        loss = criterion(logits, labels)
        total_loss += float(loss.item()) * labels.size(0); n += labels.size(0)
        preds = logits.argmax(1)
        y_true.extend(labels.cpu().numpy().tolist())
        y_pred.extend(preds.cpu().numpy().tolist())
        all_feats.append(feats.cpu().numpy())
    avg_loss = total_loss / max(n, 1)
    feats_np = np.vstack(all_feats) if len(all_feats)>0 else np.zeros((0, model.backbone.out_dim))
    return avg_loss, y_true, y_pred, feats_np

def train_text(num_epochs=20, lr=2e-5, weight_decay=0.01, patience=5,
               batch_size=8, max_len=256, oversample_short=2):
    stage = "text"
    stage_dir = ensure_dir(os.path.join(RESULTS_DIR, stage))

    tokenizer = AutoTokenizer.from_pretrained(
    "HooshvareLab/bert-base-parsbert-uncased"
)
    train_ds = OCRTextDataset(train_csv, tokenizer, max_len=max_len, oversample_short=oversample_short)
    test_ds  = OCRTextDataset(test_csv,  tokenizer, max_len=max_len, oversample_short=1)
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
    test_loader  = DataLoader(test_ds,  batch_size=batch_size, shuffle=False)

    model = TextClassifier(num_classes).to(device)
    optimizer = AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    total_steps = len(train_loader)*num_epochs
    scheduler = get_linear_schedule_with_warmup(optimizer, int(0.1*total_steps), total_steps)
    ce = nn.CrossEntropyLoss()
    ema = EMA(model, decay=0.98)

    best_acc, best_shadow = 0.0, None
    patience_counter = 0

    # histories
    train_losses, test_losses = [], []
    train_accs, test_accs = [], []
    train_f1s, test_f1s = [], []
    train_sens, test_sens = [], []
    train_spec, test_spec = [], []
    train_gm,   test_gm   = [], []
    metrics_rows = []

    for epoch in range(num_epochs):
        model.train()
        run_loss, corr, tot = 0.0, 0, 0
        for batch in train_loader:
            ids = batch["input_ids"].to(device)
            mask = batch["attention_mask"].to(device)
            labels = batch["label"]
            if not torch.is_tensor(labels):
                labels = torch.tensor(labels, dtype=torch.long)
            labels = labels.to(device)

            optimizer.zero_grad()
            logits = model(ids, mask)
            loss = ce(logits, labels)
            loss.backward()
            optimizer.step()
            scheduler.step()
            ema.update(model)

            run_loss += loss.item()
            corr += (logits.argmax(1)==labels).sum().item()
            tot += labels.size(0)

        # evaluate with EMA on train+test
        ema.apply_shadow(model)
        tr_loss, tr_y, tr_p, tr_feats = evaluate_text_full(model, train_loader, ce)
        te_loss, te_y, te_p, te_feats = evaluate_text_full(model, test_loader,  ce)
        ema.restore(model)

        tr_acc, tr_f1, tr_sens, tr_spec, tr_gm, tr_cm,tr_pc = compute_metrics(tr_y, tr_p, num_classes)
        te_acc, te_f1, te_sens, te_spec, te_gm, te_cm,te_pc = compute_metrics(te_y, te_p, num_classes)

        train_losses.append(tr_loss); test_losses.append(te_loss)
        train_accs.append(tr_acc); test_accs.append(te_acc)
        train_f1s.append(tr_f1); test_f1s.append(te_f1)
        train_sens.append(tr_sens); test_sens.append(te_sens)
        train_spec.append(tr_spec); test_spec.append(te_spec)
        train_gm.append(tr_gm);     test_gm.append(te_gm)

        metrics_rows.append([epoch+1,"train",tr_loss,tr_acc,tr_f1,tr_sens,tr_spec,tr_gm])
        metrics_rows.append([epoch+1,"test", te_loss,te_acc,te_f1,te_sens,te_spec,te_gm])

        print(f"[Text ] Epoch {epoch+1}/{num_epochs} - TrainLoss {run_loss/len(train_loader):.4f} - TrainAcc(EvalEMA) {tr_acc:.4f} - TestAcc(EvalEMA) {te_acc:.4f}")

        if te_acc > best_acc:
            best_acc = te_acc
            ema.apply_shadow(model)
            best_state = copy.deepcopy(model.state_dict())
            ema.restore(model)
            patience_counter = 0

            # محاسبه متریک‌های per-class روی تست
            _, _, _, _, _, _, te_pc = compute_metrics(te_y, te_p, num_classes)

            # ذخیره CSV
            rows = []
            for pc in te_pc:
                rows.append([stage, pc["class"], pc["acc"], pc["f1"],
                            pc["sensitivity"], pc["specificity"], pc["gmean"]])
            df = pd.DataFrame(rows, columns=["stage","class","acc","f1","sensitivity","specificity","gmean"])
            df.to_csv(os.path.join(stage_dir,"best_per_class.csv"), index=False)




        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"[Text ] Early stopping at epoch {epoch+1}")
                break

    # export EMA-averaged best
    final_model = TextClassifier(num_classes).to(device)
    final_model.load_state_dict(best_state)
    os.makedirs("checkpoints", exist_ok=True)
    torch.save(final_model.state_dict(), "checkpoints/text_best_ema.pt")
    print(f"[Text ] Best TestAcc(EMA): {best_acc:.4f}  | saved to checkpoints/text_best_ema.pt")

    # save epoch CSV + curves
    df = pd.DataFrame(metrics_rows, columns=["epoch","split","loss","acc","f1","sensitivity","specificity","gmean"])
    df.to_csv(os.path.join(stage_dir,"metrics.csv"), index=False)
    epochs = list(range(1, len(train_losses)+1))
    fig = plot_curve(epochs, train_losses, test_losses, "Text Loss", "loss")
    save_fig_dual(fig, os.path.join(stage_dir, "curve_loss"))
    fig = plot_curve(epochs, train_accs, test_accs, "Text Accuracy", "accuracy")
    save_fig_dual(fig, os.path.join(stage_dir, "curve_acc"))

    # Final CM & t-SNE with final model
    #ema.apply_shadow(final_model)

    final_model.eval()
    tr_loss, tr_y, tr_p, tr_feats = evaluate_text_full(final_model, train_loader, ce)
    te_loss, te_y, te_p, te_feats = evaluate_text_full(final_model, test_loader,  ce)
    _, _, _, _, _, tr_cm,tr_pc = compute_metrics(tr_y, tr_p, num_classes)
    _, _, _, _, _, te_cm,te_pc = compute_metrics(te_y, te_p, num_classes)
    #ema.restore(final_model)

    pd.DataFrame(tr_cm).to_csv(os.path.join(stage_dir,"cm_train.csv"), index=False)
    pd.DataFrame(te_cm).to_csv(os.path.join(stage_dir,"cm_test.csv"),  index=False)
    fig = plot_confusion(tr_cm, "Text Confusion Matrix (Train)")
    save_fig_dual(fig, os.path.join(stage_dir,"cm_train"))
    fig = plot_confusion(te_cm, "Text Confusion Matrix (Test)")
    save_fig_dual(fig, os.path.join(stage_dir,"cm_test"))

    run_tsne_and_plot(tr_feats, tr_y, "Text t-SNE (Train)", os.path.join(stage_dir,"tsne_train"))
    run_tsne_and_plot(te_feats, te_y, "Text t-SNE (Test)",  os.path.join(stage_dir,"tsne_test"))

    return "checkpoints/text_best_ema.pt"

# ======= Fusion Stage =======
# Dataset that returns (image, text) together using OCR CSV
class FusionDataset(Dataset):
    def __init__(self, csv_file, tokenizer, img_transform, max_len=256):
        self.df = pd.read_csv(csv_file)
        self.tokenizer = tokenizer
        self.img_transform = img_transform
        self.max_len = max_len

    def __len__(self): return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        path = row["path"]; label = int(row["label"])
        # image
        img = Image.open(path).convert("RGB")
        img = self.img_transform(img)
        # text
        text = clean_ocr_text(str(row["text"]))
        enc = self.tokenizer(text, padding='max_length', truncation=True,
                             max_length=self.max_len, return_tensors='pt')
        return {
            "image": img,
            "input_ids": enc["input_ids"].squeeze(0),
            "attention_mask": enc["attention_mask"].squeeze(0),
            "label": label
        }


class DIDFusionHead(nn.Module):
    """
    Dynamic Information-Density Fusion
    """
    def __init__(self, v_dim, t_dim, num_classes, bottleneck=256, p_drop=0.6, temperature=2.0):
        super().__init__()
        self.v_proj = nn.Sequential(
            nn.LayerNorm(v_dim),
            nn.Linear(v_dim, bottleneck),
            nn.GELU(),
        )
        self.t_proj = nn.Sequential(
            nn.LayerNorm(t_dim),
            nn.Linear(t_dim, bottleneck),
            nn.GELU(),
        )
        self.temp = temperature

        # density estimators (scalar per modality)
        self.v_density = nn.Sequential(nn.Linear(bottleneck, 64), nn.GELU(), nn.Linear(64,1))
        self.t_density = nn.Sequential(nn.Linear(bottleneck, 64), nn.GELU(), nn.Linear(64,1))

        # fusion + classifier
        fused_in = bottleneck * 3  # [v_proj, t_proj, weighted_sum]
        self.fusion = nn.Sequential(
            nn.LayerNorm(fused_in),
            nn.Linear(fused_in, bottleneck),
            nn.BatchNorm1d(bottleneck),
            nn.GELU(),
            nn.Dropout(p_drop),
            nn.Linear(bottleneck, num_classes)
        )

    def forward(self, v, t):
        vp = self.v_proj(v)   # [B, b]
        tp = self.t_proj(t)   # [B, b]

        dv = self.v_density(vp)  # [B,1]
        dt = self.t_density(tp)  # [B,1]
        dcat = torch.cat([dv, dt], dim=1)  # [B,2]

        w = F.softmax(dcat / self.temp, dim=1)  # adaptive weights over {vision, text}
        wv = w[:,0:1]; wt = w[:,1:2]

        fused_weighted = wv*vp + wt*tp
        fused_cat = torch.cat([vp, tp, fused_weighted], dim=1)
        logits = self.fusion(fused_cat)
        return logits, w.detach(), vp.detach(), tp.detach(), fused_weighted.detach()




class FusionModel(nn.Module):
    def __init__(self, num_classes, vision_ckpt, text_ckpt, unfreeze_backbones=True, model_name="bert-base-multilingual-cased"):
        super().__init__()
        # Vision backbone
        self.vision_backbone = VisionBackbone()
        temp_vis = VisionClassifier(num_classes)
        temp_vis.load_state_dict(torch.load(vision_ckpt, map_location="cpu"))
        self.vision_backbone.load_state_dict(temp_vis.backbone.state_dict(), strict=True)

        # Text backbone
        self.text_backbone = TextBackbone(model_name=model_name)
        temp_txt = TextClassifier(num_classes)
        temp_txt.load_state_dict(torch.load(text_ckpt, map_location="cpu"))
        self.text_backbone.load_state_dict(temp_txt.backbone.state_dict(), strict=True)

        # freeze or not
        for p in self.vision_backbone.parameters(): p.requires_grad = unfreeze_backbones
        for p in self.text_backbone.parameters():   p.requires_grad = unfreeze_backbones

        # === Fusion bottleneck: smaller capacity + stronger regularization ===
        # === DID-Fusion head (replace previous self.fusion) ===
        bottleneck_dim = 256
        self.head = DIDFusionHead(self.vision_backbone.out_dim, self.text_backbone.out_dim,
                                  num_classes, bottleneck=bottleneck_dim, p_drop=0.6, temperature=2.0)


    def forward(self, image, input_ids, attention_mask):
        v = self.vision_backbone(image)                         # [B,1024]
        t = self.text_backbone(input_ids, attention_mask)       # [B,768]
        logits, weights, vp, tp, vw = self.head(v, t)
        return logits, weights, vp, tp, vw


@torch.no_grad()
def evaluate_fusion_full(model, loader, criterion):
    model.eval()
    total_loss = 0.0; n = 0
    y_true, y_pred = [], []
    v_feats_all, t_feats_all, fused_all, w_all = [], [], [], []
    for batch in loader:
        img = batch["image"].to(device)
        ids = batch["input_ids"].to(device)
        mask = batch["attention_mask"].to(device)
        labels = torch.as_tensor(batch["label"], dtype=torch.long, device=device)
        logits, weights, vp, tp, vw = model(img, ids, mask)
        loss = criterion(logits, labels)
        total_loss += float(loss.item()) * labels.size(0); n += labels.size(0)
        preds = logits.argmax(1)
        y_true.extend(labels.cpu().numpy().tolist())
        y_pred.extend(preds.cpu().numpy().tolist())
        v_feats_all.append(vp.cpu().numpy()); t_feats_all.append(tp.cpu().numpy())
        fused_all.append(vw.cpu().numpy()); w_all.append(weights.cpu().numpy())
    avg_loss = total_loss / max(n,1)
    v_np = np.vstack(v_feats_all) if len(v_feats_all)>0 else np.zeros((0, model.vision_backbone.out_dim))
    t_np = np.vstack(t_feats_all) if len(t_feats_all)>0 else np.zeros((0, model.text_backbone.out_dim))
    f_np = np.vstack(fused_all) if len(fused_all)>0 else np.zeros((0, fused_all[0].shape[1] if fused_all else 0))
    w_np = np.vstack(w_all) if len(w_all)>0 else np.zeros((0,2))
    return avg_loss, y_true, y_pred, v_np, t_np, f_np, w_np


def train_fusion(vision_ckpt, text_ckpt, num_epochs=20, lr_head=1e-3, lr_backbone=1e-5,
                 batch_size=16, max_len=256, unfreeze_backbones=True, weight_decay=0.01, patience=6):
    stage = "fusion"
    stage_dir = ensure_dir(os.path.join(RESULTS_DIR, stage))

    tokenizer = AutoTokenizer.from_pretrained(
    "HooshvareLab/bert-base-parsbert-uncased"
)
    train_ds = FusionDataset(train_csv, tokenizer, img_transform=train_transform_img, max_len=max_len)
    test_ds  = FusionDataset(test_csv,  tokenizer, img_transform=test_transform_img, max_len=max_len)
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True,  num_workers=0, pin_memory=True)
    test_loader  = DataLoader(test_ds,  batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

    model = FusionModel(num_classes, vision_ckpt, text_ckpt, unfreeze_backbones=unfreeze_backbones).to(device)

    # param groups: heads vs (optional) backbones
    head_params = list(model.head.parameters())
    if unfreeze_backbones:
        back_params = list(model.vision_backbone.parameters()) + list(model.text_backbone.parameters())
        optimizer = optim.AdamW([
            {"params": head_params, "lr": lr_head, "weight_decay": 5e-4},    # stronger reg on head
            {"params": back_params, "lr": lr_backbone, "weight_decay": 1e-4} # milder reg for backbones
        ])
    else:
        optimizer = optim.AdamW([{"params": head_params, "lr": lr_head, "weight_decay": 5e-4}])


    total_steps = len(train_loader)*num_epochs
    scheduler = get_linear_schedule_with_warmup(optimizer, int(0.06*total_steps), total_steps)
    ce = nn.CrossEntropyLoss(label_smoothing=0.05)
    ema = EMA(model, decay=0.995)

    best_acc, best_shadow, patience_counter = 0.0, None, 0

    # histories
    train_losses, test_losses = [], []
    train_accs, test_accs = [], []
    train_f1s, test_f1s = [], []
    train_sens, test_sens = [], []
    train_spec, test_spec = [], []
    train_gm,   test_gm   = [], []
    metrics_rows = []

    for epoch in range(num_epochs):
        model.train()
        run_loss, corr, tot = 0.0, 0, 0
        for batch in train_loader:
            img = batch["image"].to(device)
            ids = batch["input_ids"].to(device)
            mask = batch["attention_mask"].to(device)
            labels = torch.as_tensor(batch["label"], dtype=torch.long, device=device)

            optimizer.zero_grad()
            logits, weights, vp, tp, vw = model(img, ids, mask)
            loss = ce(logits, labels)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            scheduler.step()
            ema.update(model)

            run_loss += loss.item()
            corr += (logits.argmax(1)==labels).sum().item()
            tot += labels.size(0)

        # eval with EMA weights on train+test
        ema.apply_shadow(model)
        tr_loss, tr_y, tr_p, tr_v, tr_t, tr_fused, tr_w  = evaluate_fusion_full(model, train_loader, ce)
        te_loss, te_y, te_p, te_v, te_t, te_fused, te_w  = evaluate_fusion_full(model, test_loader,  ce)
        ema.restore(model)

        tr_acc, tr_f1, tr_sens, tr_spec, tr_gm, tr_cm,tr_pc = compute_metrics(tr_y, tr_p, num_classes)
        te_acc, te_f1, te_sens, te_spec, te_gm, te_cm,te_pc = compute_metrics(te_y, te_p, num_classes)

        train_losses.append(tr_loss); test_losses.append(te_loss)
        train_accs.append(tr_acc); test_accs.append(te_acc)
        train_f1s.append(tr_f1); test_f1s.append(te_f1)
        train_sens.append(tr_sens); test_sens.append(te_sens)
        train_spec.append(tr_spec); test_spec.append(te_spec)
        train_gm.append(tr_gm);     test_gm.append(te_gm)

        metrics_rows.append([epoch+1,"train",tr_loss,tr_acc,tr_f1,tr_sens,tr_spec,tr_gm])
        metrics_rows.append([epoch+1,"test", te_loss,te_acc,te_f1,te_sens,te_spec,te_gm])

        print(f"[Fuse ] Epoch {epoch+1}/{num_epochs} - TrainLoss {run_loss/len(train_loader):.4f} - TrainAcc(EvalEMA) {tr_acc:.4f} - TestAcc(EvalEMA) {te_acc:.4f}")

        if te_acc>best_acc:
            best_acc = te_acc
            ema.apply_shadow(model)
            best_state = copy.deepcopy(model.state_dict())
            ema.restore(model)
            patience_counter = 0

            # محاسبه متریک‌های per-class روی تست
            _, _, _, _, _, _, te_pc = compute_metrics(te_y, te_p, num_classes)

            rows = []
            for pc in te_pc:
                rows.append([stage, pc["class"], pc["acc"], pc["f1"],
                            pc["sensitivity"], pc["specificity"], pc["gmean"]])
            df = pd.DataFrame(rows, columns=["stage","class","acc","f1","sensitivity","specificity","gmean"])
            df.to_csv(os.path.join(stage_dir,"best_per_class.csv"), index=False)
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"[Fuse ] Early stopping at epoch {epoch+1}")
                break

    # export best EMA weights
    final_model = FusionModel(num_classes, vision_ckpt, text_ckpt, unfreeze_backbones=unfreeze_backbones).to(device)
    final_model.load_state_dict(best_state)

    os.makedirs("checkpoints", exist_ok=True)
    torch.save(final_model.state_dict(), "checkpoints/fusion_best_ema.pt")
    print(f"[Fuse ] Best TestAcc(EMA): {best_acc:.4f}  | saved to checkpoints/fusion_best_ema.pt")

    # save epoch CSV + curves
    df = pd.DataFrame(metrics_rows, columns=["epoch","split","loss","acc","f1","sensitivity","specificity","gmean"])
    df.to_csv(os.path.join(stage_dir,"metrics.csv"), index=False)
    epochs_ = list(range(1, len(train_losses)+1))
    fig = plot_curve(epochs_, train_losses, test_losses, "Fusion Loss", "loss")
    save_fig_dual(fig, os.path.join(stage_dir, "curve_loss"))
    fig = plot_curve(epochs_, train_accs, test_accs, "Fusion Accuracy", "accuracy")
    save_fig_dual(fig, os.path.join(stage_dir, "curve_acc"))

    # Final CM & TSNE (on fused features)
    #ema.apply_shadow(final_model)

    final_model.eval()
    tr_loss, tr_y, tr_p, tr_v, tr_t, tr_fused, tr_w  = evaluate_fusion_full(final_model, train_loader, ce)
    te_loss, te_y, te_p, te_v, te_t, te_fused, te_w  = evaluate_fusion_full(final_model, test_loader,  ce)
    _, _, _, _, _, tr_cm,tr_pc = compute_metrics(tr_y, tr_p, num_classes)
    _, _, _, _, _, te_cm,te_pc = compute_metrics(te_y, te_p, num_classes)
    #ema.restore(final_model)
    pd.DataFrame(tr_cm).to_csv(os.path.join(stage_dir,"cm_train.csv"), index=False)
    pd.DataFrame(te_cm).to_csv(os.path.join(stage_dir,"cm_test.csv"),  index=False)
    fig = plot_confusion(tr_cm, "Fusion Confusion Matrix (Train)")
    save_fig_dual(fig, os.path.join(stage_dir,"cm_train"))
    fig = plot_confusion(te_cm, "Fusion Confusion Matrix (Test)")
    save_fig_dual(fig, os.path.join(stage_dir,"cm_test"))

    run_tsne_and_plot(tr_fused, tr_y, "Fusion t-SNE (Train)", os.path.join(stage_dir,"tsne_train"), use_all=True)
    run_tsne_and_plot(te_fused, te_y, "Fusion t-SNE (Test)",  os.path.join(stage_dir,"tsne_test"), use_all=True)

    return "checkpoints/fusion_best_ema.pt"
# Out:
# [!] CSV exists: ocr_cache/train.csv
# [!] CSV exists: ocr_cache/test.csv

# %%
# ======= Run all three stages =======
if __name__ == "__main__":
    # Stage 1: Vision
    vision_ckpt = train_vision(num_epochs=15, lr=1e-4, weight_decay=0.0)

    # Stage 2: Text
    text_ckpt = train_text(num_epochs=10, lr=3e-5, weight_decay=0.01, patience=20,
                           batch_size=8, max_len=256, oversample_short=2)


    # Stage 3: Fusion (set unfreeze_backbones=True if دیتاست بزرگ و GPU مناسب داری)
    fusion_ckpt = train_fusion(vision_ckpt, text_ckpt,
                               num_epochs=10, lr_head=1e-3, lr_backbone=1e-5,
                               batch_size=16, max_len=128, unfreeze_backbones=True,
                               weight_decay=0.01, patience=20)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [Vision] Epoch 1/15 - TrainLoss 1.3717 - TrainAcc(EvalEMA) 0.5634 - TestAcc(EvalEMA) 0.4246
# [Vision] Epoch 2/15 - TrainLoss 0.6787 - TrainAcc(EvalEMA) 0.9228 - TestAcc(EvalEMA) 0.6648
# [Vision] Epoch 3/15 - TrainLoss 0.2900 - TrainAcc(EvalEMA) 0.9969 - TestAcc(EvalEMA) 0.7207
# [Vision] Epoch 4/15 - TrainLoss 0.0966 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.7542
# [Vision] Epoch 5/15 - TrainLoss 0.0438 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.7709
# [Vision] Epoch 6/15 - TrainLoss 0.0254 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.7821
# [Vision] Epoch 7/15 - TrainLoss 0.0176 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.7709
# [Vision] Epoch 8/15 - TrainLoss 0.0132 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.7765
# [Vision] Epoch 9/15 - TrainLoss 0.0076 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.7989
# [Vision] Epoch 10/15 - TrainLoss 0.0065 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.8045
# [Vision] Epoch 11/15 - TrainLoss 0.0054 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.8045
# [Vision] Epoch 12/15 - TrainLoss 0.0043 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.7989
# [Vision] Epoch 13/15 - TrainLoss 0.0041 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.8101
# [Vision] Epoch 14/15 - TrainLoss 0.0039 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.7877
# [Vision] Epoch 15/15 - TrainLoss 0.0036 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.7989
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# [Vision] Best TestAcc(EMA): 0.8101  | saved to checkpoints/vision_best_ema.pt
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: HooshvareLab/bert-base-parsbert-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [Text ] Epoch 1/10 - TrainLoss 1.6092 - TrainAcc(EvalEMA) 0.4286 - TestAcc(EvalEMA) 0.4078
# [Text ] Epoch 2/10 - TrainLoss 1.3592 - TrainAcc(EvalEMA) 0.7092 - TestAcc(EvalEMA) 0.5475
# [Text ] Epoch 3/10 - TrainLoss 0.8453 - TrainAcc(EvalEMA) 0.8686 - TestAcc(EvalEMA) 0.6201
# [Text ] Epoch 4/10 - TrainLoss 0.4387 - TrainAcc(EvalEMA) 0.9077 - TestAcc(EvalEMA) 0.6648
# [Text ] Epoch 5/10 - TrainLoss 0.2921 - TrainAcc(EvalEMA) 0.9217 - TestAcc(EvalEMA) 0.6480
# [Text ] Epoch 6/10 - TrainLoss 0.2225 - TrainAcc(EvalEMA) 0.9244 - TestAcc(EvalEMA) 0.6480
# [Text ] Epoch 7/10 - TrainLoss 0.1921 - TrainAcc(EvalEMA) 0.9260 - TestAcc(EvalEMA) 0.6313
# [Text ] Epoch 8/10 - TrainLoss 0.1810 - TrainAcc(EvalEMA) 0.9260 - TestAcc(EvalEMA) 0.6313
# [Text ] Epoch 9/10 - TrainLoss 0.1732 - TrainAcc(EvalEMA) 0.9270 - TestAcc(EvalEMA) 0.6536
# [Text ] Epoch 10/10 - TrainLoss 0.1709 - TrainAcc(EvalEMA) 0.9270 - TestAcc(EvalEMA) 0.6369
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: HooshvareLab/bert-base-parsbert-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [Text ] Best TestAcc(EMA): 0.6648  | saved to checkpoints/text_best_ema.pt
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: HooshvareLab/bert-base-parsbert-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: HooshvareLab/bert-base-parsbert-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [Fuse ] Epoch 1/10 - TrainLoss 0.4095 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.7989
# [Fuse ] Epoch 2/10 - TrainLoss 0.2618 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.8492
# [Fuse ] Epoch 3/10 - TrainLoss 0.2567 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.8436
# [Fuse ] Epoch 4/10 - TrainLoss 0.2501 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.8492
# [Fuse ] Epoch 5/10 - TrainLoss 0.2480 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.8659
# [Fuse ] Epoch 6/10 - TrainLoss 0.2426 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.8492
# [Fuse ] Epoch 7/10 - TrainLoss 0.2465 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.8603
# [Fuse ] Epoch 8/10 - TrainLoss 0.2445 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.8715
# [Fuse ] Epoch 9/10 - TrainLoss 0.2423 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.8547
# [Fuse ] Epoch 10/10 - TrainLoss 0.2420 - TrainAcc(EvalEMA) 1.0000 - TestAcc(EvalEMA) 0.8715
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: HooshvareLab/bert-base-parsbert-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: HooshvareLab/bert-base-parsbert-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.decoder.bias               | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.decoder.weight             | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [Fuse ] Best TestAcc(EMA): 0.8715  | saved to checkpoints/fusion_best_ema.pt

# %%
import shutil
from google.colab import files

# مسیر پوشه
folder_path = "/content/results"

# مسیر فایل زیپ خروجی
output_filename = "/content/results.zip"

# ساخت فایل zip از کل پوشه
shutil.make_archive("/content/results", 'zip', folder_path)

# دانلود فایل zip
#files.download(output_filename)

# %%
import shutil
from google.colab import files

# مسیر پوشه
folder_path = "/content/checkpoints"

# مسیر فایل زیپ خروجی
output_filename = "/content/checkpoints.zip"

# ساخت فایل zip از کل پوشه
shutil.make_archive("/content/checkpoints", 'zip', folder_path)
# Out:
# '/content/checkpoints.zip'

# %%
import shutil
from google.colab import files

# مسیر پوشه
folder_path = "/content/ocr_cache"

# مسیر فایل زیپ خروجی
output_filename = "/content/ocr_cache.zip"

# ساخت فایل zip از کل پوشه
shutil.make_archive("/content/ocr_cache", 'zip', folder_path)
# Out:
# '/content/ocr_cache.zip'

# %%
# !pip list | grep -E "torch|torchvision|transformers|easyocr|split|sklearn|pandas|numpy|matplotlib|Pillow|seaborn"
# Out:
# easyocr                                  1.7.2
# geopandas                                1.1.3
# matplotlib                               3.10.0
# matplotlib-inline                        0.2.2
# matplotlib-venn                          1.1.2
# numpy                                    2.0.2
# pandas                                   2.2.2
# pandas-datareader                        0.10.0
# pandas-gbq                               0.30.0
# pandas-stubs                             2.2.2.240909
# seaborn                                  0.13.2
# sentence-transformers                    5.5.1
# sklearn-compat                           0.1.6
# sklearn-pandas                           2.2.0
# split-folders                            0.6.1
# torch                                    2.11.0+cu128
# torchao                                  0.10.0
# torchaudio                               2.11.0+cu128
# torchcodec                               0.11.0+cu128
# torchdata                                0.11.0
# torchsummary                             1.5.1
# torchtune                                0.6.1
# torchvision                              0.26.0+cu128
# transformers                             5.12.0

# %%
import pkg_resources
packages = ['torch', 'torchvision', 'transformers', 'easyocr',
            'split-folders', 'scikit-learn', 'pandas', 'numpy',
            'matplotlib', 'Pillow', 'seaborn']
for p in packages:
    try:
        print(f"{p}=={pkg_resources.get_distribution(p).version}")
    except:
        print(f"{p} not found")
# Out:
# torch==2.11.0+cu128
# torchvision==0.26.0+cu128
# transformers==5.12.0
# easyocr==1.7.2
# split-folders==0.6.1
# scikit-learn==1.6.1
# pandas==2.2.2
# numpy==2.0.2
# matplotlib==3.10.0
# Pillow==11.3.0
# seaborn==0.13.2
# /tmp/ipykernel_2446/2303861959.py:1: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources
